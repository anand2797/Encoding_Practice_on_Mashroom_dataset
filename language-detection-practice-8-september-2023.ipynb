# %% [markdown]
# <a href="https://www.kaggle.com/code/anandtalware/language-detection-practice-8-september-2023?scriptVersionId=142398817" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Language Detection

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/language-detection/Language Detection.csv

# %% [markdown]
# # nltk imports

# %%
import nltk 
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import PorterStemmer

# %% [markdown]
# # sklearn imports

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from wordcloud import WordCloud

# Naive Bayes- MultinomialNB
from sklearn.naive_bayes import MultinomialNB

# %% [markdown]
# # Data fetching in dataframe form

# %%
data = pd.read_csv('/kaggle/input/language-detection/Language Detection.csv')

# %%
data.head()
# Out:
#                                                 Text Language
# 0   Nature, in the broadest sense, is the natural...  English
# 1  "Nature" can refer to the phenomena of the phy...  English
# 2  The study of nature is a large, if not the onl...  English
# 3  Although humans are part of nature, human acti...  English
# 4  [1] The word nature is borrowed from the Old F...  English

# %%
data.tail()
# Out:
#                                                     Text Language
# 10332  ನಿಮ್ಮ ತಪ್ಪು ಏನು ಬಂದಿದೆಯೆಂದರೆ ಆ ದಿನದಿಂದ ನಿಮಗೆ ಒ...  Kannada
# 10333  ನಾರ್ಸಿಸಾ ತಾನು ಮೊದಲಿಗೆ ಹೆಣಗಾಡುತ್ತಿದ್ದ ಮಾರ್ಗಗಳನ್...  Kannada
# 10334  ಹೇಗೆ ' ನಾರ್ಸಿಸಿಸಮ್ ಈಗ ಮರಿಯನ್ ಅವರಿಗೆ ಸಂಭವಿಸಿದ ಎ...  Kannada
# 10335  ಅವಳು ಈಗ ಹೆಚ್ಚು ಚಿನ್ನದ ಬ್ರೆಡ್ ಬಯಸುವುದಿಲ್ಲ ಎಂದು ...  Kannada
# 10336  ಟೆರ್ರಿ ನೀವು ನಿಜವಾಗಿಯೂ ಆ ದೇವದೂತನಂತೆ ಸ್ವಲ್ಪ ಕಾಣು...  Kannada

# %%
print('Before any cleaning in dataset: ')
print('Total Records in dataset: ',data.shape[0])
print('Total Features in dataset: ', data.shape[1])
# Out:
# Before any cleaning in dataset:
# Total Records in dataset:  10337
# Total Features in dataset:  2

# %% [markdown]
# # Check missing values in dataset

# %%
data.isnull().sum()
# Out:
# Text        0
# Language    0
# dtype: int64

# %% [markdown]
# - Here is not any null value in our dataset.

# %% [markdown]
# # Check Duplicated records in dataset

# %%
data.duplicated().sum()
# Out:
# 66

# %% [markdown]
# - Here in dataset, we have 66  duplicate records, so we have to drop them.

# %%
# dropping duplicates
data.drop_duplicates(inplace=True)

# check again
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Normal data information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10271 entries, 0 to 10336
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Text      10271 non-null  object
#  1   Language  10271 non-null  object
# dtypes: object(2)
# memory usage: 240.7+ KB

# %%
print('After any cleaning in dataset: ')
print('Total Records in dataset: ',data.shape[0])
print('Total Features in dataset: ', data.shape[1])
# Out:
# After any cleaning in dataset:
# Total Records in dataset:  10271
# Total Features in dataset:  2

# %% [markdown]
# # EDA before preprocessing

# %% [markdown]
# ### Value counts of target column

# %%
data['Language'].value_counts()
# Out:
# Language
# English       1382
# French        1007
# Spanish        816
# Portugeese     736
# Italian        694
# Russian        688
# Sweedish       673
# Malayalam      591
# Dutch          542
# Arabic         532
# Turkish        471
# German         465
# Tamil          464
# Danish         424
# Kannada        366
# Greek          358
# Hindi           62
# Name: count, dtype: int64

# %%
# contplot for Language columns
sns.countplot(y=data['Language'])
plt.title('Value Counts for languages')

plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
# create fuction to preprocess test data

import string
punc = string.punctuation

# Define a translation table to remove punctuations
translator = str.maketrans('', '', punc)

def preprocess_text(text):
    # convert in lower case
    lower_text = text.lower()
    
    # word tokenization
    tokens = word_tokenize(text)
    
    
    # remove special charactors and punctuations
    tokens2 = [token.translate(translator) for token in tokens if token not in punc]
    
    # stemming
    stm = PorterStemmer()
    stemmed_tokens = [stm.stem(token) for token in tokens2]
    
    preprocessed_text = ' '.join(stemmed_tokens)
    return  preprocessed_text

print(preprocess_text(data['Text'][1]))
# Out:
#  natur  can refer to the phenomena of the physic world and also to life in gener

# %% [markdown]
# # Creat a new dataset which also has preprocessed text

# %%
data1 = data[['Text', 'Language']]
data1['Preprocessed_text'] = data1['Text'].apply(preprocess_text)

# %%
data1.head()
# Out:
#                                                 Text Language  \
# 0   Nature, in the broadest sense, is the natural...  English
# 1  "Nature" can refer to the phenomena of the phy...  English
# 2  The study of nature is a large, if not the onl...  English
# 3  Although humans are part of nature, human acti...  English
# 4  [1] The word nature is borrowed from the Old F...  English
#
#                                    Preprocessed_text
# 0  natur in the broadest sens is the natur physic...
# 1   natur  can refer to the phenomena of the phys...
# 2  the studi of natur is a larg if not the onli p...
# 3  although human are part of natur human activ i...
# 4  1 the word natur is borrow from the old french...

# %%
# check number of unique languages in dataset
data1['Language'].nunique()
# Out:
# 17

# %%
from wordcloud import WordCloud 
wc = WordCloud(width=800, height=500, min_font_size=15, background_color='white')

# %%
### 1. wordcloud for english language
english_df = data1[data1['Language']=='English']

english_words = english_df['Preprocessed_text'].str.cat(sep=' ')

english_wc = wc.generate(english_words)
plt.figure(figsize=(8,8))
plt.imshow(english_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
data1['Language'].unique()
# Out:
# array(['English', 'Malayalam', 'Hindi', 'Tamil', 'Portugeese', 'French',
#        'Dutch', 'Spanish', 'Greek', 'Russian', 'Danish', 'Italian',
#        'Turkish', 'Sweedish', 'Arabic', 'German', 'Kannada'], dtype=object)

# %%
languages = data1['Language'].unique()
for lang in languages:
    print()
    print('-'*10, lang,'Wordcloud','-'*10)
    lang_df = data1[data1['Language']==lang]

    lang_words = lang_df['Preprocessed_text'].str.cat(sep=' ')

    lang_wc = wc.generate(lang_words)
    plt.figure(figsize=(8,8))
    plt.imshow(lang_wc)
    plt.axis('off')
    plt.show()
    print('=='*30)
# Out:
# ---------- English Wordcloud ----------
# ============================================================
#
# ---------- Malayalam Wordcloud ----------
# ============================================================
#
# ---------- Hindi Wordcloud ----------
# ============================================================
#
# ---------- Tamil Wordcloud ----------
# ============================================================
#
# ---------- Portugeese Wordcloud ----------
# ============================================================
#
# ---------- French Wordcloud ----------
# ============================================================
#
# ---------- Dutch Wordcloud ----------
# ============================================================
#
# ---------- Spanish Wordcloud ----------
# ============================================================
#
# ---------- Greek Wordcloud ----------
# ============================================================
#
# ---------- Russian Wordcloud ----------
# ============================================================
#
# ---------- Danish Wordcloud ----------
# ============================================================
#
# ---------- Italian Wordcloud ----------
# ============================================================
#
# ---------- Turkish Wordcloud ----------
# ============================================================
#
# ---------- Sweedish Wordcloud ----------
# ============================================================
#
# ---------- Arabic Wordcloud ----------
# ============================================================
#
# ---------- German Wordcloud ----------
# ============================================================
#
# ---------- Kannada Wordcloud ----------
# ============================================================

# %%
data1[data1['Language']=='Hindi']
# Out:
#                                                    Text Language  \
# 1979  विकि-शब्दकोष (एक मुक्त शब्दकोष एवं समानांतर को...    Hindi
# 1980  [42] अंत में, विकिपीडिया एक पक्ष नहीं लेता है।...    Hindi
# 1981  बोट्स नामक कंप्यूटर प्रोग्राम के निर्माण के बा...    Hindi
# 1982               ""नहीं, हम नहीं जानते", जिमी ने कहा.    Hindi
# 1983  [60] कुछ आलोचकों का दावा है कि विकिपीडिया की ख...    Hindi
# ...                                                 ...      ...
# 2037  मैं सोच रहा था कि क्या यो मेरी मदद कर सकता है।...    Hindi
# 2038                     कैसे कुछ आइसक्रीम के बारे में?    Hindi
# 2039             क्या आप मुझे एक सवारी घर देना चाहेंगे?    Hindi
# 2040  जी बोलिये। यह बहुत अच्छा होगा, धन्यवाद। मैं ठी...    Hindi
# 2041  एक सेकंड पर लटकाओ। बस एक पल मेरे साथ सहन करो। ...    Hindi
#
#                                       Preprocessed_text
# 1979  विकिशब्दकोष एक मुक्त शब्दकोष एवं समानांतर कोष ...
# 1980  42 अंत में विकिपीडिया एक पक्ष नहीं लेता है। 43...
# 1981  बोट्स नामक कंप्यूटर प्रोग्राम के निर्माण के बा...
# 1982                    नहीं हम नहीं जानते  जिमी ने कहा
# 1983  60 कुछ आलोचकों का दावा है कि विकिपीडिया की खुल...
# ...                                                 ...
# 2037  मैं सोच रहा था कि क्या यो मेरी मदद कर सकता है।...
# 2038                      कैसे कुछ आइसक्रीम के बारे में
# 2039              क्या आप मुझे एक सवारी घर देना चाहेंगे
# 2040  जी बोलिये। यह बहुत अच्छा होगा धन्यवाद। मैं ठीक...
# 2041  एक सेकंड पर लटकाओ। बस एक पल मेरे साथ सहन करो। ...
#
# [62 rows x 3 columns]

# %% [markdown]
# # checking words counts in each language

# %%
from collections import Counter

languages = data1['Language'].unique()
a = 1
for lang in languages:
    print()
    lang_corpus = []
    lang_text = data1[data1['Language']==lang]['Preprocessed_text'].tolist()
    for i in lang_text:
        for word in i.split():
            lang_corpus.append(word)
    print(f"{a}) Number of words in {lang} : ", len(lang_corpus))
    print(f'Top 15 words in {lang}:', Counter(lang_corpus).most_common(15))
    print('='*20)
    a+=1
# Out:
# 1) Number of words in English :  30985
# Top 15 words in English: [('the', 1563), ('of', 1026), ('and', 836), ('to', 741), ('a', 697), ('in', 579), ('that', 408), ('is', 404), ('wikipedia', 361), ('you', 356), ('for', 268), ('as', 262), ('it', 251), ('are', 211), ('on', 209)]
# ====================
#
# 2) Number of words in Malayalam :  6117
# Top 15 words in Malayalam: [('ഒരു', 139), ('നിങ്ങൾ', 121), ('ഞാൻ', 116), ('നിങ്ങൾക്ക്', 88), ('ഈ', 59), ('എനിക്ക്', 59), ('ഇത്', 54), ('അത്', 47), ('വളരെ', 39), ('എന്ന്', 37), ('എന്റെ', 37), ('വിക്കിപീഡിയ', 36), ('അല്ലെങ്കിൽ', 33), ('നിങ്ങളുടെ', 31), ('അതിനാൽ', 30)]
# ====================
#
# 3) Number of words in Hindi :  14918
# Top 15 words in Hindi: [('के', 563), ('में', 397), ('है', 345), ('और', 313), ('एक', 262), ('को', 251), ('कि', 244), ('से', 233), ('हैं', 229), ('आप', 198), ('की', 188), ('w', 188), ('है।', 187), ('·', 186), ('लिए', 173)]
# ====================
#
# 4) Number of words in Tamil :  5574
# Top 15 words in Tamil: [('நீங்கள்', 183), ('நான்', 150), ('ஒரு', 123), ('என்று', 95), ('அல்லது', 56), ('மிகவும்', 53), ('மற்றும்', 47), ('இது', 44), ('இந்த', 38), ('உங்களுக்கு', 38), ('அது', 37), ('சில', 31), ('உங்கள்', 28), ('அதை', 27), ('இல்லை', 26)]
# ====================
#
# 5) Number of words in Portugeese :  16955
# Top 15 words in Portugeese: [('de', 807), ('que', 476), ('a', 402), ('e', 393), ('o', 290), ('em', 268), ('da', 266), ('você', 257), ('wikipédia', 240), ('um', 226), ('do', 204), ('uma', 195), ('para', 193), ('não', 190), ('por', 162)]
# ====================
#
# 6) Number of words in French :  23707
# Top 15 words in French: [('de', 1560), ('le', 771), ('la', 609), ('et', 525), ('à', 422), ('en', 339), ('que', 303), ('un', 278), ('vou', 272), ('est', 263), ('une', 254), ('dan', 247), ('par', 215), ('wikipédia', 196), ('qui', 174)]
# ====================
#
# 7) Number of words in Dutch :  9340
# Top 15 words in Dutch: [('je', 357), ('het', 281), ('de', 274), ('een', 252), ('en', 228), ('van', 210), ('dat', 192), ('ik', 163), ('in', 153), ('is', 145), ('niet', 122), ('al', 111), ('te', 111), ('op', 88), ('met', 77)]
# ====================
#
# 8) Number of words in Spanish :  17762
# Top 15 words in Spanish: [('de', 1072), ('la', 648), ('que', 515), ('en', 484), ('y', 394), ('el', 345), ('lo', 324), ('a', 300), ('por', 248), ('\u200b', 244), ('un', 228), ('una', 192), ('no', 190), ('wikipedia', 185), ('se', 182)]
# ====================
#
# 9) Number of words in Greek :  6392
# Top 15 words in Greek: [('να', 287), ('και', 194), ('το', 165), ('είναι', 125), ('που', 119), ('για', 106), ('δεν', 98), ('ότι', 92), ('σε', 82), ('σας', 78), ('από', 75), ('μια', 72), ('με', 69), ('θα', 69), ('αυτό', 69)]
# ====================
#
# 10) Number of words in Russian :  11509
# Top 15 words in Russian: [('в', 342), ('и', 299), ('что', 176), ('не', 168), ('вы', 150), ('на', 145), ('это', 131), ('я', 129), ('»', 119), ('«', 117), ('с', 100), ('как', 100), ('википедии', 99), ('или', 77), ('для', 67)]
# ====================
#
# 11) Number of words in Danish :  7203
# Top 15 words in Danish: [('du', 280), ('at', 225), ('er', 219), ('og', 197), ('jeg', 197), ('det', 193), ('i', 139), ('en', 133), ('ikk', 118), ('kan', 106), ('har', 90), ('på', 83), ('dig', 82), ('for', 81), ('til', 79)]
# ====================
#
# 12) Number of words in Italian :  15548
# Top 15 words in Italian: [('di', 677), ('e', 373), ('che', 330), ('in', 263), ('è', 250), ('un', 227), ('la', 215), ('il', 192), ('a', 190), ('non', 190), ('per', 180), ('una', 147), ('sono', 144), ('wikipedia', 143), ('le', 124)]
# ====================
#
# 13) Number of words in Turkish :  5702
# Top 15 words in Turkish: [('bir', 210), ('ve', 189), ('bu', 110), ('çok', 61), ('için', 60), ('da', 54), ('iyi', 43), ('ya', 36), ('o', 31), ('gibi', 29), ('de', 29), ('ne', 28), ('her', 26), ('olduğunu', 26), ('daha', 26)]
# ====================
#
# 14) Number of words in Sweedish :  13037
# Top 15 words in Sweedish: [('att', 437), ('och', 387), ('är', 283), ('du', 277), ('i', 264), ('som', 260), ('det', 230), ('en', 213), ('av', 203), ('jag', 201), ('på', 178), ('för', 166), ('wikipedia', 162), ('kan', 159), ('har', 155)]
# ====================
#
# 15) Number of words in Arabic :  9607
# Top 15 words in Arabic: [('في', 302), ('من', 259), ('،', 215), ('أن', 169), ('على', 155), ('ويكيبيديا', 137), ('ما', 96), ('لا', 86), ('إلى', 82), ('أو', 79), ('هذا', 78), ('يمكنك', 63), ('التي', 55), ('إذا', 52), ('كان', 49)]
# ====================
#
# 16) Number of words in German :  5903
# Top 15 words in German: [('sie', 240), ('ich', 191), ('und', 149), ('da', 107), ('ist', 106), ('ein', 104), ('zu', 100), ('nicht', 98), ('du', 97), ('es', 93), ('dass', 81), ('die', 81), ('in', 70), ('wenn', 64), ('sagen', 53)]
# ====================
#
# 17) Number of words in Kannada :  4126
# Top 15 words in Kannada: [('ನೀವು', 211), ('ನಾನು', 162), ('ಮತ್ತು', 147), ('ಎಂದು', 102), ('ನಿಮಗೆ', 55), ('ಅಥವಾ', 48), ('ನಿಮ್ಮ', 43), ('ಅದು', 43), ('ಈ', 40), ('ನನ್ನ', 40), ('ತುಂಬಾ', 35), ('ನನಗೆ', 34), ('ಇದು', 34), ('ಅದನ್ನು', 30), ('ಆದ್ದರಿಂದ', 28)]
# ====================

# %% [markdown]
# # # Split data as indepedent and dependent features

# %%
X = data1['Preprocessed_text']
y = data1['Language']

# %% [markdown]
#  # Train test split

# %%
X_train, X_test,y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
print('shape of X:', X.shape)
print()
print('shape of X_train: ',X_train.shape)
print('shape of ty_train: ',y_train.shape)
print('shape of X_test: ',X_test.shape)
print('shape of y_test: ',y_test.shape)
# Out:
# shape of X: (10271,)
#
# shape of X_train:  (8216,)
# shape of ty_train:  (8216,)
# shape of X_test:  (2055,)
# shape of y_test:  (2055,)

# %%
print('number of unique langues in y_train: ',y_train.nunique())
print('number of unique langues in y_test: ',y_test.nunique())
# Out:
# number of unique langues in y_train:  17
# number of unique langues in y_test:  17

# %% [markdown]
# # label encoder for talrget column

# %%
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %% [markdown]
# # Text Vectorization
# ## 1. CountVectorization

# %%
# countvectorizer
cv = CountVectorizer()
X_train_cv = cv.fit_transform(X_train).toarray()
X_test_cv = cv.transform(X_test).toarray()

print('shape of X:', X.shape)
print()
print('shape of X_train_cv: ',X_train_cv.shape)
print('shape of X_test_cv: ',X_test_cv.shape)
# Out:
# shape of X: (10271,)
#
# shape of X_train_cv:  (8216, 32215)
# shape of X_test_cv:  (2055, 32215)

# %% [markdown]
# # 2. Tf-idf Vectorization

# %%
# tf-idf vectorizer
tv = TfidfVectorizer(max_features=2500)
X_train_tv = tv.fit_transform(X_train).toarray()
X_test_tv = tv.transform(X_test).toarray()

print('shape of X:', X.shape)
print()
print('shape of X_train_tv: ',X_train_tv.shape)
print('shape of X_test_tv: ',X_test_tv.shape)
# Out:
# shape of X: (10271,)
#
# shape of X_train_tv:  (8216, 2500)
# shape of X_test_tv:  (2055, 2500)

# %% [markdown]
# # Machine Learning algorithms

# %%
# first we check only for Naive Bayes MultinomialNB with countvectorized data
mnb = MultinomialNB()
mnb.fit(X_train_cv, y_train_encoded)
y_pred_mnb_cv = mnb.predict(X_test_cv)


print("accuracy score for mnb: ",accuracy_score(y_test_encoded, y_pred_mnb_cv))
print()
print("pricision score for mnb: ",precision_score(y_test_encoded,y_pred_mnb_cv, average='micro'))
# Out:
# accuracy score for mnb:  0.9805352798053528
#
# pricision score for mnb:  0.9805352798053528

# %%
# multinomialNB with tfidf
mnb = MultinomialNB()
mnb.fit(X_train_tv, y_train_encoded)
y_pred_mnb_tv = mnb.predict(X_test_tv)


print("accuracy score for mnb: ",accuracy_score(y_test_encoded, y_pred_mnb_tv))
print()
print("pricision score for mnb: ",precision_score(y_test_encoded,y_pred_mnb_tv, average='micro'))
# Out:
# accuracy score for mnb:  0.9474452554744526
#
# pricision score for mnb:  0.9474452554744526

# %% [markdown]
# ### Here we have got better accuracy and precision score with CountVectorized data on Naive Bayes MultinomialNB Machine Learning Model, we store it in .pkl file by using joblib or pickle module for further website or app developement process.
